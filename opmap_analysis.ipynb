# %% [markdown]
# # Opmap analysis

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import pickle
import copy
import cv2
import math
from matplotlib import animation, rc
from IPython.display import HTML
# %matplotlib inline

# %%
import sys
sys.path.append("./opmap/opmap")

# %%
from RawCam import RawCam
from VmemMap import VmemMap
from PhaseMap import PhaseMap
from PhaseVarianceMap import PhaseVarianceMap
from PhaseVariancePeakMap import PhaseVariancePeakMap
from util import makeMovie

# %% [markdown]
# ## parameters

# %%
exp_dir = "/mnt/recordings/ExperimentData/"
anl_dir = "/mnt/recordings/AnalysisResult/Tomii/2017-11-23/"

df_path = "./list.csv"

delay = 5

pv_thre = 0.7

# %% [markdown]
# ## functions

# %%
def show_session(s):
    for key in s.keys(): 
        print "{0}:{1}".format(key, s[key])

# %%
def integrate_all(cam, vmem, pmap, pvmap, stim_x, stim_y ):
    
    shape = pvmap.data.shape
    phase_wf = -2.0
    phase_wt = 2.0
    phase_w = 0.1
    step = vmem.data.shape[1] /  pvmap.data.shape[1] 
    
    rgb_img = np.zeros( (shape[0]-delay, shape[1], shape[2], 3), dtype=np.uint8)
    
    #------------------
    # Camera
    #------------------
    img_cam = (  (cam.data[delay:,::step,::step] - cam.vmin) / (cam.vmax-cam.vmin)*96 ).astype(np.uint8)
    rgb_img[:,:,:,0] = img_cam
    rgb_img[:,:,:,1] = img_cam
    rgb_img[:,:,:,2] = img_cam
    
    #------------------
    # Vmem
    #------------------
    rgb_img[:,:,:,2] = ( (vmem.data[delay:,::step,::step]-vmem.vmin)*0.5*255 ).astype(np.uint8)
    #rgb_img[:,:,:,2] = 127 + ( vmem.data[delay:,::step,::step]*128 ).astype(np.uint8)
    #rgb_img[:,:,:,0] = 127 + ( - vmem.data[delay:,::step,::step]*128 ).astype(np.uint8)
    
    #------------------
    # WF
    #------------------
    mask = (( np.abs( pmap.data - phase_wf ) < phase_w )*1.0).astype(np.uint8)[:-delay,:,:]
    for i in range(3) : rgb_img[:,:,:,i] *= (1-mask)
    rgb_img[:,:,:,1] += mask*255

    #------------------
    # WT
    #------------------
    mask = (( np.abs( pmap.data - phase_wt ) < phase_w )*1.0).astype(np.uint8)[:-delay,:,:]
    for i in range(3) : rgb_img[:,:,:,i] *= (1-mask)
    rgb_img[:,:,:,0] += mask*255
    rgb_img[:,:,:,2] += mask*255
    
    #------------------
    # ROI
    #------------------
    for i in range(shape[0]-delay) : 
        for c in range(3):
            rgb_img[i,:,:,c] *= pvmap.roi[:,:].astype(np.uint8)
        
    #------------------
    # PS (#FFFFFF)
    #------------------
    mask = (( pvmap.data > pv_thre )*1.0).astype(np.uint8)[:-delay,:,:]
    for i in range(3) : rgb_img[:,:,:,i] *= (1-mask)
    for i in range(3) : rgb_img[:,:,:,i] += mask*(255*pvmap.data[:-delay,:,:]).astype(np.uint8)
        
    #------------------
    # Stim point (#FFFF00)
    #------------------
    mask = np.zeros( (shape[0]-delay, shape[1], shape[2]), dtype=np.uint8 )
    mask[ :, stim_y-1:stim_y+2, stim_x-1:stim_x+2 ] = 1
    for i in range(3) : rgb_img[:,:,:,i] *= (1-mask)
    rgb_img[:,:,:,2] += (mask*255).astype(np.uint8)
    rgb_img[:,:,:,1] += (mask*255).astype(np.uint8)        
    
    return rgb_img

# %% [markdown]
# ## load data frame

# %%
df = pd.read_csv(df_path)
print "N:",len(df)
df
# Out:
# N: 37
#         sample  session  frame_stim  speed   pre_x  pre_y  stim_x  stim_y  \
# 0   20160907-3        6         295   1575  106.50  84.50      86      68
# 1   20160907-3       10         354   1575   59.00  68.00      86      68
# 2   20160907-3       11         405   1575  102.00  75.50      86      68
# 3   20160907-3       17         355   1575   87.00  73.00      86      68
# 4   20160907-3       22         325   1575   80.33  62.67      86      68
# 5   20161019-1       19         380   1214   89.50  80.50      83      75
# 6   20161019-2        6         320   1500   52.50  26.00      62      54
# 7   20161019-2        7         160   1252   41.60  86.20      52      66
# 8   20161019-2        8         140   1252   37.67  86.33      52      66
# 9   20161019-2        9         190   1252   41.50  68.00      52      66
# 10  20161019-2       10         150   1252   41.33  88.33      52      66
# 11  20161019-2       11         250   1252   49.33  79.67      52      66
# 12  20161019-2       12         130   1252   35.50  90.50      52      66
# 13  20161019-2       13         140   1252   37.00  87.50      52      66
# 14  20161019-2       14         150   1252   40.25  90.00      52      66
# 15  20161019-2       15         160   1252   56.50  90.50      67      65
# 16  20161019-2       16         170   1252   57.60  91.20      67      65
# 17  20161019-2       17         180   1252   57.00  89.00      67      65
# 18  20161019-2       18         190   1252   55.75  90.00      67      65
# 19  20161019-2       19         200   1252   57.25  84.00      67      65
# 20  20161019-2       20         210   1252   56.67  75.33      67      65
# 21  20161019-2       21         230   1252   60.50  81.50      67      65
# 22  20161019-2       22         250   1252   63.50  86.50      67      65
# 23  20161019-2       23         270   1252   69.33  91.67      67      65
# 24  20161019-2       24         290   1252   68.50  93.50      67      65
# 25  20161019-3       24         260    882   57.33  59.67      60      75
# 26  20161019-3       25         250    882   64.33  60.33      60      75
# 27  20161021-1        9         170   1633   46.50  74.00      81      68
# 28  20161021-1       10         160   1633   78.00  38.50      75      51
# 29  20161021-1       11         160   1633   40.50  74.50      77      59
# 30  20161021-1       12         175   1633   54.33  80.67      77      59
# 31  20161021-1       13         165   1633   99.50  67.50      77      65
# 32  20161021-1       14         180   1633   55.20  81.80      77      65
# 33  20161021-1       16         185   1633   56.00  83.50      77      65
# 34  20161021-2       10         180   2529   41.50  71.50      66      50
# 35  20161021-2       11         190   2529   47.00  64.25      66      50
# 36  20161021-2       12         205   2529   48.50  61.50      66      50
#
#      distance  stim_phase  sw_induced  sw_collision  sw_sustained  fb_angle  \
# 0   16.708187        2.85        True          True         False  1.555173
# 1   17.142857        0.99        True          True          True  1.555173
# 2   11.219427        2.51        True          True         False  1.555173
# 3    3.237473        1.16        True          True         False  1.555173
# 4    4.940882        1.47        True          True          True  1.555173
# 5    7.013751       -2.17       False         False         False  0.960070
# 6   19.711813       -1.04       False         False         False  1.570796
# 7   18.146993       -2.58        True          True          True  1.570796
# 8   19.866480        1.73        True          True          True  1.570796
# 9    8.537364       -0.98       False         False         False  1.570796
# 10  19.767004        2.41        True          True          True  1.570796
# 11  11.124848        1.30       False         False         False  1.570796
# 12  23.592740        1.13       False         False         False  1.570796
# 13  20.938861        1.60        True          True          True  1.570796
# 14  21.343409        2.46        True          True          True  1.570796
# 15  22.026489       -2.93        True          True          True  1.570796
# 16  22.232611       -2.51        True          True          True  1.570796
# 17  20.766773       -2.15       False         False         False  1.570796
# 18  21.896678       -1.91       False         False         False  1.570796
# 19  17.057204       -1.29       False         False         False  1.570796
# 20  11.668391       -0.50       False         False         False  1.570796
# 21  14.164655        0.01       False         False         False  1.570796
# 22  17.398579        0.42       False         False         False  1.570796
# 23  21.383056        1.13       False         False         False  1.570796
# 24  22.795085        1.55       False         False         False  1.570796
# 25  17.642605       -1.73       False         False         False  1.015041
# 26  17.342040       -2.27       False         False         False  1.015041
# 27  21.443878       -2.60        True          True          True  1.237212
# 28   7.871990        2.24        True         False         False  1.237212
# 29  24.283380        1.55        True         False         False  1.237212
# 30  19.204585        2.97        True         False         False  1.237212
# 31  13.863113        1.76        True          True         False  1.237212
# 32  16.853861        0.22        True          True          True  1.237212
# 33  17.138153       -2.96        True         False         False  1.237212
# 34  12.888894       -2.40        True          True          True  1.341269
# 35   9.391064       -2.30       False         False         False  1.341269
# 36   8.280107       -1.58       False         False         False  1.341269
#
#     stim_angle
# 0     0.877464
# 1     1.555173
# 2     1.116836
# 3     0.084045
# 4     1.497037
# 5     0.257813
# 6     0.327098
# 7     0.475458
# 8     0.613987
# 9     1.382575
# 10    0.445757
# 11    0.192890
# 12    0.592697
# 13    0.609163
# 14    0.455280
# 15    0.390607
# 16    0.344474
# 17    0.394791
# 18    0.422854
# 19    0.474118
# 20    0.785398
# 21    0.375271
# 22    0.161375
# 23    0.087143
# 24    0.052583
# 25    0.383317
# 26    0.842766
# 27    1.409403
# 28    0.569129
# 29    1.502800
# 30    1.141532
# 31    1.126555
# 32    1.247799
# 33    1.182189
# 34    1.080051
# 35    1.156823
# 36    1.218943

# %%
for i in range(len(df)):
    
    s = df.loc[i,:]
    
    sample = s["sample"]
    session = s["session"]
    target = "{0}/{1}/C001H001S{2:0>4}".format(exp_dir, sample, session)    
    save_dir = target.replace(exp_dir, anl_dir)
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    
    print "{0}:{1}".format(i, target)
    
    if 'cam' in locals() : del(cam)
    if 'vmem' in locals() : del(vmem)
    if 'pmap' in locals() : del(pmap)
    if 'pvmap' in locals() : del(pvmap)
    if 'pvpmap' in locals() : del(pvpmap)

    cam = RawCam(
        path = target,
        cam_type = 'sa4', 
        image_height = 512, image_width = 512, 
        frame_start = 0, frame_end = 500 )
    vmem = VmemMap( cam )
    vmem_ = copy.deepcopy(vmem)
    vmem_.setDiffRange(diff_min=64)
    vmem_.morphROI(closing=12)
    vmem_.morphROI(erosion=6)
    vmem_.smooth(15)
    pmap = PhaseMap( vmem_ )
    pvmap = PhaseVarianceMap(pmap, size=5)
    pvpmap = PhaseVariancePeakMap(pvmap)
    core_log = pvpmap.getCoreLog()
    rgb_img = integrate_all(cam, vmem_, pmap, pvmap, stim_x=s["stim_x"], stim_y=s["stim_y"])
    
    # np.savez(os.path.join(save_dir, "vmem"), vmem.data)
    # np.savez(os.path.join(save_dir, "pmap"), pmap.data)
    # np.savez(os.path.join(save_dir, "pvmap"), pvmap.data)
    # np.savez(os.path.join(save_dir, "pvpmap"), pvpmap.data)

    with open(os.path.join(save_dir, "center.csv"), 'w') as outf:
        for row in core_log:
            str_line = ''
            for elem in row:
                str_line += '{0},'.format(elem)
            str_line.rstrip(',')
            outf.write(str_line)
            outf.write('\n')
            
    with open(os.path.join(save_dir, "elec_phase.log"), 'w') as outf:
        elec_phase = pmap.data[:, s["stim_y"], s["stim_x"]]
        for i, v in enumerate(elec_phase):
            outf.write('{0} {1}\n'.format(i, v))

    dirs = []

    #d = os.path.join( save_dir , "vmem");  vmem.saveImage(d); dirs.append(d)
    #d = os.path.join( save_dir , "pmap"); pmap.saveImage(d); dirs.append(d)
    #d = os.path.join( save_dir , "pvmap"); pvmap.saveImage(d); dirs.append(d)
    #d = os.path.join( save_dir , "pvpmap"); pvpmap.saveImage(d); dirs.append(d)

    d = os.path.join( save_dir , "all")
    if not os.path.exists(d) : os.mkdir(d)
    dirs.append(d)
    for i, img in enumerate(rgb_img):
        #im = plt.imshow(img)
        #plt.savefig(os.path.join(d, "{0:0>6}.png".format(i)))
        cv2.putText(img,"{0:0>4}ms".format(i), (4,16), cv2.FONT_HERSHEY_PLAIN, 0.6, (255,255,255))
        cv2.imwrite(os.path.join(d, "{0:0>6}.png".format(i)), img)
        
    for d in dirs: makeMovie(d)
# Out:
# 0:/mnt/recordings/ExperimentData//20160907-3/C001H001S0006
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20160907-3/C001H001S0006/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20160907-3/C001H001S0006/all.mp4"
# 1:/mnt/recordings/ExperimentData//20160907-3/C001H001S0010
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20160907-3/C001H001S0010/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20160907-3/C001H001S0010/all.mp4"
# 2:/mnt/recordings/ExperimentData//20160907-3/C001H001S0011
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20160907-3/C001H001S0011/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20160907-3/C001H001S0011/all.mp4"
# 3:/mnt/recordings/ExperimentData//20160907-3/C001H001S0017
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20160907-3/C001H001S0017/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20160907-3/C001H001S0017/all.mp4"
# 4:/mnt/recordings/ExperimentData//20160907-3/C001H001S0022
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20160907-3/C001H001S0022/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20160907-3/C001H001S0022/all.mp4"
# 5:/mnt/recordings/ExperimentData//20161019-1/C001H001S0019
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-1/C001H001S0019/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-1/C001H001S0019/all.mp4"
# 6:/mnt/recordings/ExperimentData//20161019-2/C001H001S0006
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0006/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0006/all.mp4"
# 7:/mnt/recordings/ExperimentData//20161019-2/C001H001S0007
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0007/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0007/all.mp4"
# 8:/mnt/recordings/ExperimentData//20161019-2/C001H001S0008
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0008/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0008/all.mp4"
# 9:/mnt/recordings/ExperimentData//20161019-2/C001H001S0009
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0009/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0009/all.mp4"
# 10:/mnt/recordings/ExperimentData//20161019-2/C001H001S0010
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0010/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0010/all.mp4"
# 11:/mnt/recordings/ExperimentData//20161019-2/C001H001S0011
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0011/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0011/all.mp4"
# 12:/mnt/recordings/ExperimentData//20161019-2/C001H001S0012
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0012/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0012/all.mp4"
# 13:/mnt/recordings/ExperimentData//20161019-2/C001H001S0013
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0013/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0013/all.mp4"
# 14:/mnt/recordings/ExperimentData//20161019-2/C001H001S0014
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0014/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0014/all.mp4"
# 15:/mnt/recordings/ExperimentData//20161019-2/C001H001S0015
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0015/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0015/all.mp4"
# 16:/mnt/recordings/ExperimentData//20161019-2/C001H001S0016
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0016/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0016/all.mp4"
# 17:/mnt/recordings/ExperimentData//20161019-2/C001H001S0017
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0017/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0017/all.mp4"
# 18:/mnt/recordings/ExperimentData//20161019-2/C001H001S0018
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0018/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0018/all.mp4"
# 19:/mnt/recordings/ExperimentData//20161019-2/C001H001S0019
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0019/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0019/all.mp4"
# 20:/mnt/recordings/ExperimentData//20161019-2/C001H001S0020
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0020/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0020/all.mp4"
# 21:/mnt/recordings/ExperimentData//20161019-2/C001H001S0021
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0021/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0021/all.mp4"
# 22:/mnt/recordings/ExperimentData//20161019-2/C001H001S0022
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0022/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0022/all.mp4"
# 23:/mnt/recordings/ExperimentData//20161019-2/C001H001S0023
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0023/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0023/all.mp4"
# 24:/mnt/recordings/ExperimentData//20161019-2/C001H001S0024
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0024/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-2/C001H001S0024/all.mp4"
# 25:/mnt/recordings/ExperimentData//20161019-3/C001H001S0024
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-3/C001H001S0024/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-3/C001H001S0024/all.mp4"
# 26:/mnt/recordings/ExperimentData//20161019-3/C001H001S0025
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-3/C001H001S0025/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161019-3/C001H001S0025/all.mp4"
# 27:/mnt/recordings/ExperimentData//20161021-1/C001H001S0009
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161021-1/C001H001S0009/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161021-1/C001H001S0009/all.mp4"
# 28:/mnt/recordings/ExperimentData//20161021-1/C001H001S0010
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161021-1/C001H001S0010/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161021-1/C001H001S0010/all.mp4"
# 29:/mnt/recordings/ExperimentData//20161021-1/C001H001S0011
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161021-1/C001H001S0011/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161021-1/C001H001S0011/all.mp4"
# 30:/mnt/recordings/ExperimentData//20161021-1/C001H001S0012
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161021-1/C001H001S0012/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161021-1/C001H001S0012/all.mp4"
# 31:/mnt/recordings/ExperimentData//20161021-1/C001H001S0013
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161021-1/C001H001S0013/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161021-1/C001H001S0013/all.mp4"
# 32:/mnt/recordings/ExperimentData//20161021-1/C001H001S0014
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161021-1/C001H001S0014/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161021-1/C001H001S0014/all.mp4"
# 33:/mnt/recordings/ExperimentData//20161021-1/C001H001S0016
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161021-1/C001H001S0016/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161021-1/C001H001S0016/all.mp4"
# 34:/mnt/recordings/ExperimentData//20161021-2/C001H001S0010
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161021-2/C001H001S0010/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161021-2/C001H001S0010/all.mp4"
# 35:/mnt/recordings/ExperimentData//20161021-2/C001H001S0011
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161021-2/C001H001S0011/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161021-2/C001H001S0011/all.mp4"
# 36:/mnt/recordings/ExperimentData//20161021-2/C001H001S0012
# ffmpeg -r 15 -y -i "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161021-2/C001H001S0012/all/%06d.png" -c:v libx264 -pix_fmt yuv420p -qscale 0 "/mnt/recordings/AnalysisResult/Tomii/2017-11-23//20161021-2/C001H001S0012/all.mp4"
